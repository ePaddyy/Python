# %%
greeting = "hello world!"
print(greeting)
# Out:
# hello world!

# %%
meaning = 43
print("")

if meaning > 10:
    print("right on !")
else:
    print("not today")
# Out:
# right on !

# %%
first = "paddy"
print(type(first))
print(type(first) is str)
print(isinstance(first, str))
# Out:
# <class 'str'>
# True
# True

# %%
food = "pizza"
print(type(food))
print(type(food) is str)
print(isinstance(food, str))
# Out:
# <class 'str'>
# True
# True

# %%
name = "paddy"
print(name[:])
print(name[1:])
print(name[-1:])
print(name[1:-1])
print(name[1:-2])
# Out:
# paddy
# addy
# y
# add
# ad

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\emman\anaconda3\python.exe

# %%
# import sys
# import random
# from enum import Enum

# game_count = 0

# def play_rps():

#     class RPS(Enum):
#         ROCK = 1
#         PAPER = 2
#         SCISSORS = 3

#     # while True:

#     print("")
    
#     playerchoice = input(
#         "Enter.... \n1 for rock \n2 for paper \n3 for scissors:\n\n"
#     )

#     # try:
#     #     player = int(playerchoice)
#     # except ValueError:
#     #     print("Invalid input. Please enter a number from 1 to 3.")
        

#     if playerchoice not in ["1", "2", "3"]:
#         print("Invalid Input")
#         print("Try again. Enter a number from 1 to 3")
#         return play_rps()

#     player = int(playerchoice)
#     computerchoice = random.choice("123")
#     computer= int(computerchoice)

#     print("")
#     print("You chose " + str(RPS(player)).replace("RPS.", "") + ".")
#     print("Computer chose " + str(RPS(computer)).replace("RPS.", "") + ".")
#     print("")

#     def decide_winner(player, computer):
#         if player == 1 and computer == 3:
#             return "🎉 You win!"
#         elif player == 2 and computer == 1:
#             return "🎉 You win!"
#         elif player == 3 and computer == 2:
#             return "🎉 You win!"
#         elif player == computer:
#             return "😲 Tie!"
#         else:
#             return "😞 You lose! Computer wins!"

#     game_result = decide_winner(player, computer)

#     print(game_result)

#     global game_count
#     game_count += 1

#     print("\nGame Count: " + str(game_count))

#     print("play again")

#     while True:
#         playagain = input("\nPlay again?\nY for Yes\nQ for Quit: ")

#         if playagain.lower() not in ["y", "q"]:
#             continue

#         else:
#             break

#     if playagain.lower() == "y":
#         return play_rps()
#     else:
#         print("\n🎉🎉🎉🎉🎉🎉")
#         print("Thank You for playing!\n")
#         sys.exit("Bye! 👋")

# play_rps()
# Out:
# Invalid Input
# Try again. Enter a number from 1 to 3
#
#
# You chose ROCK.
# Computer chose SCISSORS.
#
# 🎉 You win!
#
# Game Count: 1
# play again
#
#
# You chose ROCK.
# Computer chose ROCK.
#
# 😲 Tie!
#
# Game Count: 2
# play again
#
# 🎉🎉🎉🎉🎉🎉
# Thank You for playing!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Bye! 👋
# c:\Users\emman\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import sys
import random
from enum import Enum


def rps():
    game_count = 0
    player_wins = 0
    computer_wins = 0

    def play_rps():
        nonlocal player_wins
        nonlocal computer_wins

        class RPS(Enum):
            ROCK = 1
            PAPER = 2
            SCISSORS = 3

        # while True:

        print("")
        
        playerchoice = input(
            "Enter.... \n1 for rock \n2 for paper \n3 for scissors:\n\n"
        )

        # try:
        #     player = int(playerchoice)
        # except ValueError:
        #     print("Invalid input. Please enter a number from 1 to 3.")
            

        if playerchoice not in ["1", "2", "3"]:
            print("Invalid Input")
            print("Try again. Enter a number from 1 to 3")
            return play_rps()

        player = int(playerchoice)
        computerchoice = random.choice("123")
        computer= int(computerchoice)

        print("")
        print(
            f"You chose {RPS(player).replace("RPS.", "").title()}."
        )
        print(
            f"Computer chose {RPS(computer).replace("RPS.", "").title()}."
        )
        print("")

        def decide_winner(player, computer):
            nonlocal player_wins
            nonlocal computer_wins
            if player == 1 and computer == 3:
                player_wins += 1
                return "🎉 You win!"
            elif player == 2 and computer == 1:
                player_wins += 1
                return "🎉 You win!"
            elif player == 3 and computer == 2:
                player_wins += 1
                return "🎉 You win!"
            elif player == computer:
                return "😲 Tie!"
            else:
                computer_wins += 1
                return "😞 You lose! Computer wins!"

        game_result = decide_winner(player, computer)

        print(game_result)

        nonlocal game_count
        game_count += 1

        print(f"\nGame Count: {str(game_count)}")
        print(f"\nPlayer wins: {str(player_wins)}")
        print(f"\nComputer wins: {str(computer_wins)}")

        print("play again")

        while True:
            playagain = input("\nPlay again?\nY for Yes\nQ for Quit: ")

            if playagain.lower() not in ["y", "q"]:
                continue

            else:
                break

        if playagain.lower() == "y":
            return play_rps()
        else:
            print("\n🎉🎉🎉🎉🎉🎉")
            print("Thank You for playing!\n")
            sys.exit("Bye! 👋")

    play_rps()

rps()
# Out:
# You chose ROCK.
# Computer chose PAPER.
#
# 😞 You lose! Computer wins!
#
# Game Count: 1
#
# Player wins: 0
#
# Computer wins: 1
# play again
#
#
# You chose SCISSORS.
# Computer chose PAPER.
#
# 🎉 You win!
#
# Game Count: 2
#
# Player wins: 1
#
# Computer wins: 1
# play again
#
#
# You chose SCISSORS.
# Computer chose SCISSORS.
#
# 😲 Tie!
#
# Game Count: 3
#
# Player wins: 1
#
# Computer wins: 1
# play again
#
#
# You chose PAPER.
# Computer chose ROCK.
#
# 🎉 You win!
#
# Game Count: 4
#
# Player wins: 2
#
# Computer wins: 1
# play again
#
# 🎉🎉🎉🎉🎉🎉
# Thank You for playing!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Bye! 👋
# c:\Users\emman\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
list_1 = ["paddy", "adams", "debs"]

list_1.append("ojo")
list_1.extend("john")
list_1.insert(0, "eman")
list_1[0] = "dio"
list_1.pop(6)
list_1.remove("j")
list_1.sort()
print(list_1)
print(type(list_1))

list_2 = list_1.copy()
# Out:
# ['adams', 'debs', 'dio', 'h', 'n', 'ojo', 'paddy']
# <class 'list'>

# %%
mytuple = ("paddy", "eman", 1, 2, 3)
print(type(mytuple))

# mylist = list(tuple)
# newtuple = tuple(list1)
# print(type(newtuple))
print(list_1)
num = 2
paddy = tuple(list_1)
print(paddy)
# Out:
# <class 'tuple'>
# ['adams', 'debs', 'dio', 'h', 'n', 'ojo', 'paddy']
# ('adams', 'debs', 'dio', 'h', 'n', 'ojo', 'paddy')

# %%
band = {
    "vocals":"plant",
    "guitar":"page"
}

band2 = dict(vocals ="plant", guitar = "page")
print(band.keys())
print(band2.values())
print("guitar" in band)
print("apple" in band)
band["vocals"] = "coverdale"
print(band)
# Out:
# dict_keys(['vocals', 'guitar'])
# dict_values(['plant', 'page'])
# True
# False
# {'vocals': 'coverdale', 'guitar': 'page'}

# %%
value = 1
while value <= 10:
    value = value + 1
   
    
    if value == 6:
        continue
    print(value)
# Out:
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 10
# 11

# %%
names = ["paddy", "adams", "debs"]
actions = ["eats", "fucks", "plays"]
time = ["errday", "once", "more than once"]

for x in names:
    for y in actions:
        for z in time:
            print(x + " " + y + " " + z)
# Out:
# paddy eats errday
# paddy eats once
# paddy eats more than once
# paddy fucks errday
# paddy fucks once
# paddy fucks more than once
# paddy plays errday
# paddy plays once
# paddy plays more than once
# adams eats errday
# adams eats once
# adams eats more than once
# adams fucks errday
# adams fucks once
# adams fucks more than once
# adams plays errday
# adams plays once
# adams plays more than once
# debs eats errday
# debs eats once
# debs eats more than once
# debs fucks errday
# debs fucks once
# debs fucks more than once
# debs plays errday
# debs plays once
# debs plays more than once

# %%
def hello(a):
    print("hello world " + a)
hello("paddy")
# Out:
# hello world paddy

# %%
import numpy as np

a = np.array([1,2,3,4,5])
a**4
# Out:
# array([  1,  16,  81, 256, 625])

# %%
def parent_function(person, coins):
    #coins = 3

    def play_game():
        nonlocal coins
        coins -= 1

        if coins > 1:
            print("\n" + person + " has " + str(coins) + " coins left")
        elif coins == 1:
            print("\n" + person + " has " + str(coins) + " coins left")

        else:
            print("\n" + person + " is out of coins ")

    return play_game

tommy = parent_function("Tommy", 3)
Jenny = parent_function("Jenny", 5)

tommy()
tommy()

Jenny()
# Out:
# Tommy has 2 coins left
#
# Tommy has 1 coins left
#
# Jenny has 4 coins left

# %%
import math

for item in dir(math):
    print(item)
math.sqrt(16)
# Out:
# __doc__
# __loader__
# __name__
# __package__
# __spec__
# acos
# acosh
# asin
# asinh
# atan
# atan2
# atanh
# cbrt
# ceil
# comb
# copysign
# cos
# cosh
# degrees
# dist
# e
# erf
# erfc
# exp
# exp2
# expm1
# fabs
# factorial
# floor
# fma
# fmod
# frexp
# fsum
# gamma
# gcd
# hypot
# inf
# isclose
# isfinite
# isinf
# isnan
# isqrt
# lcm
# ldexp
# lgamma
# log
# log10
# log1p
# log2
# modf
# nan
# nextafter
# perm
# pi
# pow
# prod
# radians
# remainder
# sin
# sinh
# sqrt
# sumprod
# tan
# tanh
# tau
# trunc
# ulp

# %%
def number_summary(numbers):
    count = 0
    total = 0

    for i in numbers:
        count += 1
        total += i

    # Handle empty list
    if count == 0:
        return {
            "total": 0,
            "count": 0,
            "mean": None,
            "min": None,
            "max": None
        }

    mean = total / count

    minimum = numbers[0]
    maximum = numbers[0]

    for i in numbers:
        if i < minimum:
            minimum = i

        if i > maximum:
            maximum = i

    return {
        "total": total,
        "count": count,
        "mean": mean,
        "min": minimum,
        "max": maximum
    }


print(number_summary([1, 2, 3, 4, 5]))
print(number_summary([-10, -5, -20]))
print(number_summary([]))
# Out:
# {'total': 15, 'count': 5, 'mean': 3.0, 'min': 1, 'max': 5}
# {'total': -35, 'count': 3, 'mean': -11.666666666666666, 'min': -20, 'max': -5}
# {'total': 0, 'count': 0, 'mean': None, 'min': None, 'max': None}

# %%
import sys
import random
# import random
# from enum import Enum



def guess_number():
    game_count = 0
    player_wins = 0
    computer_wins = 0  
    player_win_percentage = 0
    computer_win_percentage = 0  

    def play_guess():
        nonlocal player_wins
        nonlocal computer_wins
        nonlocal player_win_percentage
        nonlocal computer_win_percentage
        print("")

        playerchoice = input("Enter a number between 1 and 3:\n\n")
        computerchoice = random.randint(1, 3)

        player = int(playerchoice)
        computer = int(computerchoice)

        while True:
            try:
                if player < 1 or player > 3:
                    print("Enter a number between 1 and 3")
                    continue

                break

            except ValueError:
                print("Invalid input. Please enter a valid number.")

        print("")
        print(f"You chose {player}")
        print(f"Computer chose {computer}")

        def decide_winner(player, computer):
            nonlocal player_wins
            nonlocal computer_wins
            nonlocal player_win_percentage
            nonlocal computer_win_percentage

            if player == computer:
                player_wins += 1
                return "🎉 You win!"
            else:
                computer_wins += 1
                return "😢 Computer wins!"
            
        game_result = decide_winner(player, computer)
        print(game_result)

        nonlocal game_count
        game_count += 1
        print(f"\nGame Count: {str(game_count)}")
        print(f"\nPlayer Wins: {str(player_wins)}")
        print(f"\nComputer Wins: {str(computer_wins)}")

        player_win_percentage = (player_wins / game_count) * 100
        computer_win_percentage = (computer_wins / game_count) * 100
        print(f"\nPlayer Win Percentage: {player_win_percentage:.2f}%")
        print(f"Computer Win Percentage: {computer_win_percentage:.2f}%")

        print("")
        print("play again")
        while True:
            playagain = input("\nPlay again?\nY for Yes\nQ for Quit: ")

            if playagain.lower() not in ["y", "q"]:
                continue
            else:
                break

        if playagain.lower() == "y":
            return play_guess()
        else:
            print("\n🎉🎉🎉🎉🎉🎉")
            print("Thank You for playing!\n")
            sys.exit("Bye! 👋")
    play_guess()

guess_number()
# Out:
# You chose 2
# Computer chose 2
# 🎉 You win!
#
# Game Count: 1
#
# Player Wins: 1
#
# Computer Wins: 0
#
# Player Win Percentage: 100.00%
# Computer Win Percentage: 0.00%
#
# play again
#
#
# You chose 1
# Computer chose 2
# 😢 Computer wins!
#
# Game Count: 2
#
# Player Wins: 1
#
# Computer Wins: 1
#
# Player Win Percentage: 50.00%
# Computer Win Percentage: 50.00%
#
# play again
#
# 🎉🎉🎉🎉🎉🎉
# Thank You for playing!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Bye! 👋
